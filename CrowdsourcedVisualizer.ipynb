# %%
import time
import gmaps
import pandas as pd
import numpy as np
#import gmaps.datasets 
from IPython.display import display

st = time.time()

bio = pd.read_csv("nys-data.csv", "\t")
#print(fullCSV.head())

st2 = time.time()

def divideSpace(lonMin, lonMax, latMin, latMax, numSpaces=100):
    Lon = np.arange(lonMin, lonMax, (lonMax - lonMin) / numSpaces)
    Lat = np.arange(latMin, latMax, (latMax - latMin) / numSpaces)
    return (Lon, Lat)

#### dividing Broome County into 100 evenly divided spaces
# lonMin = -76.127601
# lonMax = -75.360264
# latMin = 41.997124
# latMax = 42.418692

#### dividing New York into 1000 evenly divided spaces
lonMin = -79.765
lonMax = -71.790277
latMin = 40.494444
latMax = 45.01166666666666
numSpaces = 100
lonDiff = (lonMax - lonMin) / numSpaces
latDiff = (latMax - latMin) / numSpaces

Lon, Lat = divideSpace(lonMin, lonMax, latMin, latMax, numSpaces)

bio_counts = np.zeros((numSpaces, numSpaces))

mt = time.time()
# for a in range(len(bio)):
#     tempLat = bio['decimalLatitude'].values[a]
#     tempLon = bio['decimalLongitude'].values[a]
#     for b1 in range(numSpaces):
#         if Lat[b1] - lonDiff <= tempLat < Lat[b1] + lonDiff:
#             for b2 in range(numSpaces):
#                 if Lon[b2] - latDiff <= tempLon < Lon[b2] + latDiff:
#                     bio_counts[b1,b2] += 1
#                     break
#             break

lat_indices = np.digitize(bio['decimalLatitude'].values, Lat) - 1
lon_indices = np.digitize(bio['decimalLongitude'].values, Lon) - 1
for i in range(len(bio)):
    bio_counts[lat_indices[i], lon_indices[i]] += 1

            
mt2 = time.time()

# for a in range(len(bio)):
#     for b1 in range(numSpaces):
#         if Lat[b1] - ((lonMax - lonMin) / numSpaces) <= bio['decimalLatitude'].values[a] < Lat[b1] + ((lonMax - lonMin) / numSpaces):
#             for b2 in range(numSpaces):
#                 if Lon[b2] - ((latMax - latMin) / numSpaces) <= bio['decimalLongitude'].values[a] < Lon[b2] + ((latMax - latMin) / numSpaces):
#                     bio_counts[b1,b2] += 1

gmaps.configure(api_key="YOUR API KEY HERE")

longitude_values = [Lon,]*numSpaces
#latitude_values = [Lat,]*100
latitude_values = np.repeat(Lat,numSpaces)
bio_counts.resize((numSpaces**2,))

heatmap_data = {'Counts': bio_counts, 'latitude': latitude_values, 'longitude': np.concatenate(longitude_values)}
df = pd.DataFrame.from_dict(heatmap_data, orient='index')
df = df.transpose()

locations = df[['latitude', 'longitude']]


weights = df['Counts']

# fig = gmaps.figure()
# heatmap_layer = gmaps.heatmap_layer(locations, weights=weights)
# fig.add_layer(heatmap_layer(locations, weights=weights))
# fig


####


gmaps.configure(api_key="AIzaSyCmGdwvfQAv_SgZCUUMKzbUSRv0JNKU-CM")

new_york_coordinates = (40.7128, -74.0060)
binghamton_coordinates = (42.0987, -75.9180)

fig = gmaps.figure(center=binghamton_coordinates, zoom_level=6)
heatmap_layer = gmaps.heatmap_layer(locations, weights=weights)
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))

et = time.time()
print(f'{et - st} seconds')
print(f'{st2 - st} seconds to read csv')
print(f'{mt - st} seconds for whole start section')
print(f'{mt2 - mt} seconds for mid section')
print(f'{et - mt2} seconds for end section')

fig



#marker_locations = [(40.7128, -74.0060)]
#markers = gmaps.marker_layer(marker_locations)

# fig.add_layer(markers)
# fig
# Out:
# 10.196669101715088 seconds
# 8.947576999664307 seconds to read csv
# 8.947576999664307 seconds for whole start section
# 0.8069062232971191 seconds for mid section
# 0.4421858787536621 seconds for end section
# Figure(layout=FigureLayout(height='420px'))
